# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
def generate_answer_dataframe(file_path: str) -> pd.DataFrame:
    """
    Reads a JSON file and generates a DataFrame with section information.
    
    Args:
        file_path (str): Path to the JSON file.
        
    Returns:
        pd.DataFrame: DataFrame containing section information.
    """
    with open(file_path, 'r') as file:
        data = json.load(file)

    rows = []
    for name, sections in data.items():
        for number, section_name in sections.items():
            rows.append({'pdf_name': name, 'section_number': number, 'section_title': section_name, 'source_db': "manual"})

    return pd.DataFrame(rows)

# %%
def load_ground_truth_and_predictions(parquet_file, json_file):
    """Load your dataset and JSON predictions"""
    df = pd.read_parquet(parquet_file)
    
    manual_validation = generate_answer_dataframe(json_file)

    concatenated_pdf = pd.concat([df, manual_validation], ignore_index=True)
    
    return concatenated_pdf

# %%
manual_validation = generate_answer_dataframe("/home/pramos/Documents/AutoSLR/validations/regex_validation/answer_template.json")
manual_validation
# Out:
#              pdf_name section_number  \
# 0    amraoui2022_splc              1
# 1    amraoui2022_splc              2
# 2    amraoui2022_splc              3
# 3    amraoui2022_splc              4
# 4    amraoui2022_splc              5
# ..                ...            ...
# 684      Vitui2021ese              5
# 685      Vitui2021ese              6
# 686      Vitui2021ese              7
# 687      Vitui2021ese              8
# 688      Vitui2021ese              9
#
#                                          section_title source_db
# 0                                         INTRODUCTION    manual
# 1                     FROM PARTIAL KNOWLEDGE TO AN SPL    manual
# 2    DESIGNING AN EVOLVABLE SPL WITH PARTIAL KNOWLEDGE    manual
# 3                                          APPLICATION    manual
# 4                                           DISCUSSION    manual
# ..                                                 ...       ...
# 684                                 Case Study Results    manual
# 685                                        Discussions    manual
# 686                                Threats to Validity    manual
# 687                                       Related Work    manual
# 688                                        Conclusions    manual
#
# [689 rows x 4 columns]

# %%
df = load_ground_truth_and_predictions("/home/pramos/Documents/AutoSLR/validations/regex_validation/results/section_grouped.parquet","/home/pramos/Documents/AutoSLR/validations/regex_validation/answer_template.json")
df
# Out:
#           pdf_name section_number                        section_title  \
# 0      Krishna2021              1                         INTRODUCTION
# 1      Krishna2021              2                           MOTIVATION
# 2      Krishna2021              3    DEFINITIONS AND PROBLEM STATEMENT
# 3      Krishna2021              4  BEETLE: BELLWETHER TRANSFER LEARNER
# 4      Krishna2021              5      OTHER TRANSFER LEARNING METHODS
# ...            ...            ...                                  ...
# 7574  Vitui2021ese              5                   Case Study Results
# 7575  Vitui2021ese              6                          Discussions
# 7576  Vitui2021ese              7                  Threats to Validity
# 7577  Vitui2021ese              8                         Related Work
# 7578  Vitui2021ese              9                          Conclusions
#
#               source_db
# 0     specific_regex.db
# 1     specific_regex.db
# 2     specific_regex.db
# 3     specific_regex.db
# 4     specific_regex.db
# ...                 ...
# 7574             manual
# 7575             manual
# 7576             manual
# 7577             manual
# 7578             manual
#
# [7579 rows x 4 columns]

# %%
def remove_unwanted_sections_flexible(df):
    """
    Remove rows with section titles containing specific keywords
    """
    # Define keywords to remove (case-insensitive)
    keywords_to_remove = ['abstract', 'keywords', 'ccs concepts', 'references', 
                         'acm reference format']
    
    # Create a mask - keep rows that don't contain any of these keywords
    mask = True
    for keyword in keywords_to_remove:
        mask = mask & (~df['section_title'].str.lower().str.contains(keyword, na=False))
    
    # Add regex pattern for appendix variations
    # This matches: appendix, appendices, appendix a, appendix b, etc.
    appendix_pattern = r'appendi(x|ces)(\s+[a-z])?'
    mask = mask & (~df['section_title'].str.lower().str.contains(appendix_pattern, na=False, regex=True))
    
    # Filter the dataframe
    filtered_df = df[mask].copy()
    return filtered_df

# %%
df = remove_unwanted_sections_flexible(df)
df
# Out:
# /tmp/ipykernel_78181/3370365013.py:17: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = mask & (~df['section_title'].str.lower().str.contains(appendix_pattern, na=False, regex=True))
#           pdf_name section_number                        section_title  \
# 0      Krishna2021              1                         INTRODUCTION
# 1      Krishna2021              2                           MOTIVATION
# 2      Krishna2021              3    DEFINITIONS AND PROBLEM STATEMENT
# 3      Krishna2021              4  BEETLE: BELLWETHER TRANSFER LEARNER
# 4      Krishna2021              5      OTHER TRANSFER LEARNING METHODS
# ...            ...            ...                                  ...
# 7574  Vitui2021ese              5                   Case Study Results
# 7575  Vitui2021ese              6                          Discussions
# 7576  Vitui2021ese              7                  Threats to Validity
# 7577  Vitui2021ese              8                         Related Work
# 7578  Vitui2021ese              9                          Conclusions
#
#               source_db
# 0     specific_regex.db
# 1     specific_regex.db
# 2     specific_regex.db
# 3     specific_regex.db
# 4     specific_regex.db
# ...                 ...
# 7574             manual
# 7575             manual
# 7576             manual
# 7577             manual
# 7578             manual
#
# [7331 rows x 4 columns]

# %%
def check_correct_predictions(concatenated_df):
    """
    Check how many automatic predictions are correct by comparing with manual validation
    """
    # Separate manual (ground truth) and automatic predictions
    manual_data = concatenated_df[concatenated_df['source_db'] == 'manual']
    auto_data = concatenated_df[concatenated_df['source_db'] != 'manual']
    
    # Create sets of (pdf_name, section_title) for easy comparison
    manual_sections = set(zip(manual_data['pdf_name'], manual_data['section_title']))
    auto_sections = set(zip(auto_data['pdf_name'], auto_data['section_title']))
    
    # Find correct predictions (sections that exist in both)
    correct_predictions = auto_sections.intersection(manual_sections)
    
    # Calculate metrics by source_db
    results = {}
    total_manual_sections = len(manual_sections)
    
    for source in auto_data['source_db'].unique():
        source_data = auto_data[auto_data['source_db'] == source]
        source_sections = set(zip(source_data['pdf_name'], source_data['section_title']))
        
        # True Positives: predictions that match manual validation
        true_positives = len(source_sections.intersection(manual_sections))
        
        # False Positives: predictions that don't exist in manual validation
        false_positives = len(source_sections - manual_sections)
        
        total_predictions = len(source_sections)
        
        # Precision: TP / (TP + FP) = TP / Total_Predictions
        precision = true_positives / total_predictions if total_predictions > 0 else 0
        
        # Coverage: TP / Total_Manual_Sections (how much of manual data was found)
        coverage = true_positives / total_manual_sections if total_manual_sections > 0 else 0
        
        results[source] = {
            'total_predictions': total_predictions,
            'total_manual_sections': total_manual_sections,
            'true_positives': true_positives,
            'false_positives': false_positives,
            'precision': precision,
            'coverage': coverage  # New metric!
        }
    
    return results, correct_predictions

# %%
results, correct_preds = check_correct_predictions(df)

# %%
for source, metrics in results.items():
    print(f"\nSource: {source}")
    print(f"  Total predictions: {metrics['total_predictions']}")
    print(f"  Total manual sections: {metrics['total_manual_sections']}")
    print(f"  True Positives: {metrics['true_positives']}")
    print(f"  False Positives: {metrics['false_positives']}")
    print(f"  Precision: {metrics['precision']:.2%}")
    print(f"  Coverage: {metrics['coverage']:.2%}")  # New metric!
    print("-" * 40)
# Out:
# Source: specific_regex.db
#   Total predictions: 953
#   Total manual sections: 689
#   True Positives: 546
#   False Positives: 407
#   Precision: 57.29%
#   Coverage: 79.25%
# ----------------------------------------
#
# Source: voting_policy.db
#   Total predictions: 688
#   Total manual sections: 689
#   True Positives: 479
#   False Positives: 209
#   Precision: 69.62%
#   Coverage: 69.52%
# ----------------------------------------
#
# Source: local_llms.db
#   Total predictions: 535
#   Total manual sections: 689
#   True Positives: 378
#   False Positives: 157
#   Precision: 70.65%
#   Coverage: 54.86%
# ----------------------------------------
#
# Source: generic_regex.db
#   Total predictions: 1367
#   Total manual sections: 689
#   True Positives: 555
#   False Positives: 812
#   Precision: 40.60%
#   Coverage: 80.55%
# ----------------------------------------
#
# Source: ORC_tag_extraction.db
#   Total predictions: 750
#   Total manual sections: 689
#   True Positives: 605
#   False Positives: 145
#   Precision: 80.67%
#   Coverage: 87.81%
# ----------------------------------------
#
# Source: extern_llm-gemini.db
#   Total predictions: 712
#   Total manual sections: 689
#   True Positives: 603
#   False Positives: 109
#   Precision: 84.69%
#   Coverage: 87.52%
# ----------------------------------------
#
# Source: tagged_regex.db
#   Total predictions: 716
#   Total manual sections: 689
#   True Positives: 531
#   False Positives: 185
#   Precision: 74.16%
#   Coverage: 77.07%
# ----------------------------------------

# %%
def detailed_comparison(concatenated_df):
    """
    Detailed comparison showing correct and incorrect predictions by PDF
    """
    manual_data = concatenated_df[concatenated_df['source_db'] == 'manual']
    auto_data = concatenated_df[concatenated_df['source_db'] != 'manual']
    
    # Group by PDF to compare
    results_by_pdf = {}
    
    for pdf_name in auto_data['pdf_name'].unique():
        # Get manual sections for this PDF
        manual_sections_for_pdf = set(
            manual_data[manual_data['pdf_name'] == pdf_name]['section_title']
        )
        
        # Get auto predictions for this PDF
        auto_sections_for_pdf = auto_data[auto_data['pdf_name'] == pdf_name]
        
        correct = []
        incorrect = []
        
        for _, row in auto_sections_for_pdf.iterrows():
            if row['section_title'] in manual_sections_for_pdf:
                correct.append((row['section_title'], row['source_db']))
            else:
                incorrect.append((row['section_title'], row['source_db']))
        
        results_by_pdf[pdf_name] = {
            'manual_sections': manual_sections_for_pdf,
            'correct_predictions': correct,
            'incorrect_predictions': incorrect
        }
    
    return results_by_pdf

# Usage
detailed_results = detailed_comparison(df)

# Print detailed results for each PDF
for pdf_name, results in detailed_results.items():
    print(f"\nPDF: {pdf_name}")
    print(f"Manual sections: {results['manual_sections']}")
    print(f"Correct predictions: {results['correct_predictions']}")
    print(f"Incorrect predictions: {results['incorrect_predictions']}")
# Out:
# PDF: Krishna2021
# Manual sections: {'OTHER TRANSFER LEARNING METHODS', 'BEETLE: BELLWETHER TRANSFER LEARNER', 'DEFINITIONS AND PROBLEM STATEMENT', 'INTRODUCTION', 'MOTIVATION', 'EXPERIMENTAL SETUP', 'DISCUSSION', 'CONCLUSION', 'RESULTS', 'RELATED WORK', 'THREATS TO VALIDITY'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('MOTIVATION', 'specific_regex.db'), ('DEFINITIONS AND PROBLEM STATEMENT', 'specific_regex.db'), ('BEETLE: BELLWETHER TRANSFER LEARNER', 'specific_regex.db'), ('OTHER TRANSFER LEARNING METHODS', 'specific_regex.db'), ('EXPERIMENTAL SETUP', 'specific_regex.db'), ('RESULTS', 'specific_regex.db'), ('DISCUSSION', 'specific_regex.db'), ('RELATED WORK', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('INTRODUCTION', 'voting_policy.db'), ('RELATED WORK', 'voting_policy.db'), ('CONCLUSION', 'voting_policy.db'), ('MOTIVATION', 'voting_policy.db'), ('DEFINITIONS AND PROBLEM STATEMENT', 'voting_policy.db'), ('BEETLE: BELLWETHER TRANSFER LEARNER', 'voting_policy.db'), ('OTHER TRANSFER LEARNING METHODS', 'voting_policy.db'), ('EXPERIMENTAL SETUP', 'voting_policy.db'), ('RESULTS', 'voting_policy.db'), ('DISCUSSION', 'voting_policy.db'), ('THREATS TO VALIDITY', 'voting_policy.db'), ('INTRODUCTION', 'local_llms.db'), ('DEFINITIONS AND PROBLEM STATEMENT', 'local_llms.db'), ('EXPERIMENTAL SETUP', 'local_llms.db'), ('RESULTS', 'local_llms.db'), ('DISCUSSION', 'local_llms.db'), ('RELATED WORK', 'local_llms.db'), ('CONCLUSION', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('MOTIVATION', 'generic_regex.db'), ('DEFINITIONS AND PROBLEM STATEMENT', 'generic_regex.db'), ('BEETLE: BELLWETHER TRANSFER LEARNER', 'generic_regex.db'), ('OTHER TRANSFER LEARNING METHODS', 'generic_regex.db'), ('EXPERIMENTAL SETUP', 'generic_regex.db'), ('RESULTS', 'generic_regex.db'), ('DISCUSSION', 'generic_regex.db'), ('RELATED WORK', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('MOTIVATION', 'ORC_tag_extraction.db'), ('DEFINITIONS AND PROBLEM STATEMENT', 'ORC_tag_extraction.db'), ('BEETLE: BELLWETHER TRANSFER LEARNER', 'ORC_tag_extraction.db'), ('OTHER TRANSFER LEARNING METHODS', 'ORC_tag_extraction.db'), ('EXPERIMENTAL SETUP', 'ORC_tag_extraction.db'), ('RESULTS', 'ORC_tag_extraction.db'), ('DISCUSSION', 'ORC_tag_extraction.db'), ('THREATS TO VALIDITY', 'ORC_tag_extraction.db'), ('RELATED WORK', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('MOTIVATION', 'extern_llm-gemini.db'), ('DEFINITIONS AND PROBLEM STATEMENT', 'extern_llm-gemini.db'), ('BEETLE: BELLWETHER TRANSFER LEARNER', 'extern_llm-gemini.db'), ('OTHER TRANSFER LEARNING METHODS', 'extern_llm-gemini.db'), ('EXPERIMENTAL SETUP', 'extern_llm-gemini.db'), ('RESULTS', 'extern_llm-gemini.db'), ('DISCUSSION', 'extern_llm-gemini.db'), ('THREATS TO VALIDITY', 'extern_llm-gemini.db'), ('RELATED WORK', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('MOTIVATION', 'tagged_regex.db'), ('DEFINITIONS AND PROBLEM STATEMENT', 'tagged_regex.db'), ('BEETLE: BELLWETHER TRANSFER LEARNER', 'tagged_regex.db'), ('OTHER TRANSFER LEARNING METHODS', 'tagged_regex.db'), ('EXPERIMENTAL SETUP', 'tagged_regex.db'), ('RESULTS', 'tagged_regex.db'), ('DISCUSSION', 'tagged_regex.db'), ('THREATS TO VALIDITY', 'tagged_regex.db'), ('RELATED WORK', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db')]
# Incorrect predictions: []
#
# PDF: tërnava2022
# Manual sections: set()
# Correct predictions: []
# Incorrect predictions: [('INSA Rennes', 'specific_regex.db'), ('Introduction', 'specific_regex.db'), ('Background and motivation', 'specific_regex.db'), ('Research questions', 'specific_regex.db'), ('Experimental Protocol', 'specific_regex.db'), ('Based on our last check on February 2022', 'specific_regex.db'), ('Results', 'specific_regex.db'), ('Discussion', 'specific_regex.db'), ('Threats to validity', 'specific_regex.db'), ('Related Work', 'specific_regex.db'), ('Conclusion', 'specific_regex.db')]
#
# PDF: Kaltenecker2019
# Manual sections: {'INTRODUCTION', 'ACKNOWLEDGMENTS', 'EXPERIMENT SETUP', 'CONCLUSION', 'RESULTS', 'DISTANCE-BASED SAMPLING', 'PRELIMINARIES'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('PRELIMINARIES', 'specific_regex.db'), ('EXPERIMENT SETUP', 'specific_regex.db'), ('RESULTS', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('ACKNOWLEDGMENTS', 'specific_regex.db'), ('INTRODUCTION', 'local_llms.db'), ('EXPERIMENT SETUP', 'local_llms.db'), ('RESULTS', 'local_llms.db'), ('CONCLUSION', 'local_llms.db'), ('ACKNOWLEDGMENTS', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('PRELIMINARIES', 'generic_regex.db'), ('EXPERIMENT SETUP', 'generic_regex.db'), ('RESULTS', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('ACKNOWLEDGMENTS', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('PRELIMINARIES', 'ORC_tag_extraction.db'), ('EXPERIMENT SETUP', 'ORC_tag_extraction.db'), ('RESULTS', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('ACKNOWLEDGMENTS', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('PRELIMINARIES', 'extern_llm-gemini.db'), ('DISTANCE-BASED SAMPLING', 'extern_llm-gemini.db'), ('EXPERIMENT SETUP', 'extern_llm-gemini.db'), ('RESULTS', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('ACKNOWLEDGMENTS', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('PRELIMINARIES', 'tagged_regex.db'), ('EXPERIMENT SETUP', 'tagged_regex.db'), ('RESULTS', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db'), ('ACKNOWLEDGMENTS', 'tagged_regex.db')]
# Incorrect predictions: [('Compression time', 'local_llms.db'), ('Solving time', 'local_llms.db'), ('Compression time', 'local_llms.db'), ('Runtime', 'local_llms.db'), ('Encoding time', 'local_llms.db'), ('Distance', 'generic_regex.db'), ('Compression time', 'generic_regex.db'), ('Response time', 'generic_regex.db'), ('Solving time', 'generic_regex.db'), ('Solving time', 'generic_regex.db'), ('Time', 'generic_regex.db'), ('Compilation time', 'generic_regex.db'), ('Compression time', 'generic_regex.db'), ('Runtime', 'generic_regex.db'), ('Encoding time', 'generic_regex.db'), ('Encoding time', 'generic_regex.db')]
#
# PDF: Muhlbauer2020
# Manual sections: {'AN ALGORITHM FOR CHANGE POINT DETECTION', 'EVALUATION', 'INTRODUCTION', 'ACKNOWLEDGMENTS', 'DISCUSSION', 'CONCLUSION', 'CONFIGURATION-DEPENDENT CHANGE POINTS', 'RELATED WORK'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('EVALUATION', 'specific_regex.db'), ('DISCUSSION', 'specific_regex.db'), ('RELATED WORK', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('ACKNOWLEDGMENTS', 'specific_regex.db'), ('INTRODUCTION', 'voting_policy.db'), ('EVALUATION', 'voting_policy.db'), ('DISCUSSION', 'voting_policy.db'), ('RELATED WORK', 'voting_policy.db'), ('CONCLUSION', 'voting_policy.db'), ('ACKNOWLEDGMENTS', 'voting_policy.db'), ('INTRODUCTION', 'local_llms.db'), ('EVALUATION', 'local_llms.db'), ('DISCUSSION', 'local_llms.db'), ('RELATED WORK', 'local_llms.db'), ('CONCLUSION', 'local_llms.db'), ('ACKNOWLEDGMENTS', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('EVALUATION', 'generic_regex.db'), ('DISCUSSION', 'generic_regex.db'), ('RELATED WORK', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('ACKNOWLEDGMENTS', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('AN ALGORITHM FOR CHANGE POINT DETECTION', 'ORC_tag_extraction.db'), ('EVALUATION', 'ORC_tag_extraction.db'), ('DISCUSSION', 'ORC_tag_extraction.db'), ('RELATED WORK', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('ACKNOWLEDGMENTS', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('EVALUATION', 'extern_llm-gemini.db'), ('DISCUSSION', 'extern_llm-gemini.db'), ('RELATED WORK', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('ACKNOWLEDGMENTS', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('EVALUATION', 'tagged_regex.db'), ('DISCUSSION', 'tagged_regex.db'), ('RELATED WORK', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db'), ('ACKNOWLEDGMENTS', 'tagged_regex.db')]
# Incorrect predictions: [('Exploration: new commits', 'specific_regex.db'), ('AN ALGORITHM FOR CHANGE POINT', 'specific_regex.db'), ('Time', 'specific_regex.db'), ('LRZIP', 'specific_regex.db'), ('OGGENC', 'specific_regex.db'), ('Iterations Required for Termination', 'specific_regex.db'), ('Exploration: new commits', 'voting_policy.db'), ('Time', 'voting_policy.db'), ('Iterations Required for Termination', 'voting_policy.db'), ('AN ALGORITHM FOR CHANGE POINT', 'voting_policy.db'), ('AN ALGORITHM FOR CHANGE POINT', 'local_llms.db'), ('LRZIP', 'local_llms.db'), ('Iterations Required for Termination', 'local_llms.db'), ('Exploration: new commits', 'generic_regex.db'), ('AN ALGORITHM FOR CHANGE POINT', 'generic_regex.db'), ('Time', 'generic_regex.db'), ('LRZIP', 'generic_regex.db'), ('OGGENC', 'generic_regex.db'), ('Iterations Required for Termination', 'generic_regex.db'), ('Exploration: new commits', 'tagged_regex.db'), ('AN ALGORITHM FOR CHANGE POINT', 'tagged_regex.db')]
#
# PDF: Silva2023
# Manual sections: {'Threats to validity', 'Results', 'Introduction', 'Background', 'Conclusion', 'Study settings'}
# Correct predictions: [('Introduction', 'specific_regex.db'), ('Background', 'specific_regex.db'), ('Study settings', 'specific_regex.db'), ('Results', 'specific_regex.db'), ('Threats to validity', 'specific_regex.db'), ('Conclusion', 'specific_regex.db'), ('Introduction', 'voting_policy.db'), ('Background', 'voting_policy.db'), ('Study settings', 'voting_policy.db'), ('Results', 'voting_policy.db'), ('Threats to validity', 'voting_policy.db'), ('Conclusion', 'voting_policy.db'), ('Introduction', 'local_llms.db'), ('Study settings', 'local_llms.db'), ('Results', 'local_llms.db'), ('Introduction', 'generic_regex.db'), ('Background', 'generic_regex.db'), ('Study settings', 'generic_regex.db'), ('Results', 'generic_regex.db'), ('Threats to validity', 'generic_regex.db'), ('Conclusion', 'generic_regex.db'), ('Introduction', 'ORC_tag_extraction.db'), ('Background', 'ORC_tag_extraction.db'), ('Study settings', 'ORC_tag_extraction.db'), ('Results', 'ORC_tag_extraction.db'), ('Threats to validity', 'ORC_tag_extraction.db'), ('Conclusion', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('Background', 'extern_llm-gemini.db'), ('Study settings', 'extern_llm-gemini.db'), ('Results', 'extern_llm-gemini.db'), ('Threats to validity', 'extern_llm-gemini.db'), ('Conclusion', 'extern_llm-gemini.db'), ('Introduction', 'tagged_regex.db'), ('Background', 'tagged_regex.db'), ('Study settings', 'tagged_regex.db'), ('Results', 'tagged_regex.db'), ('Threats to validity', 'tagged_regex.db'), ('Conclusion', 'tagged_regex.db')]
# Incorrect predictions: [('Importance of measures for the', 'local_llms.db'), ('FM of the first 50 to calculate the comparison measures by this', 'generic_regex.db'), ('More than 10', 'generic_regex.db'), ('Correlation analysis', 'generic_regex.db'), ('Importance of measures for the', 'generic_regex.db'), ('Importance of measures for the', 'generic_regex.db'), ('Declaration of competing interest', 'extern_llm-gemini.db'), ('Data availability', 'extern_llm-gemini.db'), ('Refactorings rules', 'extern_llm-gemini.db'), ('Feature model evaluation form', 'extern_llm-gemini.db'), ('FM of the first 50 to calculate the comparison measures by this', 'tagged_regex.db')]
#
# PDF: Salman2023
# Manual sections: {'The proposed approach for locating features implementations', 'Related work', 'Introduction', 'Background', 'Results and discussion', 'Conclusion and future work'}
# Correct predictions: [('Introduction', 'specific_regex.db'), ('Background', 'specific_regex.db'), ('Related work', 'specific_regex.db'), ('The proposed approach for locating features implementations', 'specific_regex.db'), ('Results and discussion', 'specific_regex.db'), ('Conclusion and future work', 'specific_regex.db'), ('Introduction', 'voting_policy.db'), ('Background', 'voting_policy.db'), ('Related work', 'voting_policy.db'), ('The proposed approach for locating features implementations', 'voting_policy.db'), ('Results and discussion', 'voting_policy.db'), ('Conclusion and future work', 'voting_policy.db'), ('Introduction', 'local_llms.db'), ('Related work', 'local_llms.db'), ('The proposed approach for locating features implementations', 'local_llms.db'), ('Results and discussion', 'local_llms.db'), ('Conclusion and future work', 'local_llms.db'), ('Introduction', 'generic_regex.db'), ('Background', 'generic_regex.db'), ('Related work', 'generic_regex.db'), ('The proposed approach for locating features implementations', 'generic_regex.db'), ('Results and discussion', 'generic_regex.db'), ('Conclusion and future work', 'generic_regex.db'), ('Introduction', 'ORC_tag_extraction.db'), ('Background', 'ORC_tag_extraction.db'), ('Related work', 'ORC_tag_extraction.db'), ('The proposed approach for locating features implementations', 'ORC_tag_extraction.db'), ('Results and discussion', 'ORC_tag_extraction.db'), ('Conclusion and future work', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('Background', 'extern_llm-gemini.db'), ('Related work', 'extern_llm-gemini.db'), ('The proposed approach for locating features implementations', 'extern_llm-gemini.db'), ('Results and discussion', 'extern_llm-gemini.db'), ('Conclusion and future work', 'extern_llm-gemini.db'), ('Introduction', 'tagged_regex.db'), ('Background', 'tagged_regex.db'), ('Related work', 'tagged_regex.db'), ('The proposed approach for locating features implementations', 'tagged_regex.db'), ('Results and discussion', 'tagged_regex.db'), ('Conclusion and future work', 'tagged_regex.db')]
# Incorrect predictions: [('Activity Diagram', 'local_llms.db'), ('Activity Diagram', 'generic_regex.db'), ('Sequence Diagram', 'generic_regex.db'), ('UseCase Diagram', 'generic_regex.db'), ('Collaboration Diagram', 'generic_regex.db'), ('Deployment Diagram', 'generic_regex.db'), ('Cognitive Support', 'generic_regex.db'), ('Product2', 'generic_regex.db'), ('Product3', 'generic_regex.db'), ('Scenario 2', 'generic_regex.db'), ('Product2', 'generic_regex.db'), ('Product3', 'generic_regex.db'), ('Product4', 'generic_regex.db'), ('Scenario 3', 'generic_regex.db'), ('Product2', 'generic_regex.db'), ('Product3', 'generic_regex.db'), ('Product4', 'generic_regex.db'), ('Product5', 'generic_regex.db'), ('Product6', 'generic_regex.db'), ('Product7', 'generic_regex.db'), ('Scenario 4', 'generic_regex.db'), ('Product2', 'generic_regex.db'), ('Product3', 'generic_regex.db'), ('Product4', 'generic_regex.db'), ('Product5', 'generic_regex.db'), ('Product6', 'generic_regex.db'), ('Product7', 'generic_regex.db'), ('Product8', 'generic_regex.db'), ('Product9', 'generic_regex.db'), ('Product10', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('Avg', 'generic_regex.db'), ('Scenario', 'generic_regex.db'), ('CRediT authorship contribution statement', 'extern_llm-gemini.db'), ('Declaration of competing interest', 'extern_llm-gemini.db'), ('Data availability', 'extern_llm-gemini.db'), ('Activity Diagram', 'tagged_regex.db'), ('Sequence Diagram', 'tagged_regex.db'), ('UseCase Diagram', 'tagged_regex.db'), ('Collaboration Diagram', 'tagged_regex.db'), ('Deployment Diagram', 'tagged_regex.db'), ('Cognitive Support', 'tagged_regex.db'), ('Product2', 'tagged_regex.db'), ('Product3', 'tagged_regex.db'), ('Product2', 'tagged_regex.db'), ('Product3', 'tagged_regex.db'), ('Product4', 'tagged_regex.db'), ('Product2', 'tagged_regex.db'), ('Product3', 'tagged_regex.db'), ('Product4', 'tagged_regex.db'), ('Product5', 'tagged_regex.db'), ('Product6', 'tagged_regex.db'), ('Product7', 'tagged_regex.db'), ('Product2', 'tagged_regex.db'), ('Product3', 'tagged_regex.db'), ('Product4', 'tagged_regex.db'), ('Product5', 'tagged_regex.db'), ('Product6', 'tagged_regex.db'), ('Product7', 'tagged_regex.db'), ('Product8', 'tagged_regex.db'), ('Product9', 'tagged_regex.db'), ('Product10', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db'), ('Avg', 'tagged_regex.db'), ('Scenario', 'tagged_regex.db')]
#
# PDF: Iqbal2023
# Manual sections: {'Motivation and Insights', 'Introduction', 'RQ3: Sensitivity and Scalability', 'Evaluation', 'Conclusion', 'Cameo Design', 'RQ2: Severity of Environmental Changes', 'Limitations', 'RQ1: Effectiveness in Design Explorations', 'Additional Related Work'}
# Correct predictions: [('Introduction', 'specific_regex.db'), ('Motivation and Insights', 'specific_regex.db'), ('Cameo Design', 'specific_regex.db'), ('Evaluation', 'specific_regex.db'), ('RQ1: Effectiveness in Design Explorations', 'specific_regex.db'), ('RQ2: Severity of Environmental Changes', 'specific_regex.db'), ('RQ3: Sensitivity and Scalability', 'specific_regex.db'), ('Additional Related Work', 'specific_regex.db'), ('Limitations', 'specific_regex.db'), ('Conclusion', 'specific_regex.db'), ('Introduction', 'voting_policy.db'), ('Conclusion', 'voting_policy.db'), ('Motivation and Insights', 'voting_policy.db'), ('Cameo Design', 'voting_policy.db'), ('Evaluation', 'voting_policy.db'), ('RQ1: Effectiveness in Design Explorations', 'voting_policy.db'), ('RQ2: Severity of Environmental Changes', 'voting_policy.db'), ('RQ3: Sensitivity and Scalability', 'voting_policy.db'), ('Additional Related Work', 'voting_policy.db'), ('Limitations', 'voting_policy.db'), ('Introduction', 'local_llms.db'), ('Motivation and Insights', 'local_llms.db'), ('Evaluation', 'local_llms.db'), ('RQ1: Effectiveness in Design Explorations', 'local_llms.db'), ('RQ2: Severity of Environmental Changes', 'local_llms.db'), ('RQ3: Sensitivity and Scalability', 'local_llms.db'), ('Additional Related Work', 'local_llms.db'), ('Limitations', 'local_llms.db'), ('Conclusion', 'local_llms.db'), ('Introduction', 'generic_regex.db'), ('Motivation and Insights', 'generic_regex.db'), ('Cameo Design', 'generic_regex.db'), ('Evaluation', 'generic_regex.db'), ('RQ1: Effectiveness in Design Explorations', 'generic_regex.db'), ('RQ2: Severity of Environmental Changes', 'generic_regex.db'), ('RQ3: Sensitivity and Scalability', 'generic_regex.db'), ('Additional Related Work', 'generic_regex.db'), ('Limitations', 'generic_regex.db'), ('Conclusion', 'generic_regex.db'), ('Introduction', 'ORC_tag_extraction.db'), ('Motivation and Insights', 'ORC_tag_extraction.db'), ('Cameo Design', 'ORC_tag_extraction.db'), ('Evaluation', 'ORC_tag_extraction.db'), ('RQ1: Effectiveness in Design Explorations', 'ORC_tag_extraction.db'), ('RQ2: Severity of Environmental Changes', 'ORC_tag_extraction.db'), ('RQ3: Sensitivity and Scalability', 'ORC_tag_extraction.db'), ('Additional Related Work', 'ORC_tag_extraction.db'), ('Limitations', 'ORC_tag_extraction.db'), ('Conclusion', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('Motivation and Insights', 'extern_llm-gemini.db'), ('Evaluation', 'extern_llm-gemini.db'), ('RQ1: Effectiveness in Design Explorations', 'extern_llm-gemini.db'), ('RQ2: Severity of Environmental Changes', 'extern_llm-gemini.db'), ('RQ3: Sensitivity and Scalability', 'extern_llm-gemini.db'), ('Additional Related Work', 'extern_llm-gemini.db'), ('Limitations', 'extern_llm-gemini.db'), ('Conclusion', 'extern_llm-gemini.db'), ('Introduction', 'tagged_regex.db'), ('Motivation and Insights', 'tagged_regex.db'), ('Cameo Design', 'tagged_regex.db'), ('Evaluation', 'tagged_regex.db'), ('RQ1: Effectiveness in Design Explorations', 'tagged_regex.db'), ('RQ2: Severity of Environmental Changes', 'tagged_regex.db'), ('RQ3: Sensitivity and Scalability', 'tagged_regex.db'), ('Additional Related Work', 'tagged_regex.db'), ('Limitations', 'tagged_regex.db'), ('Conclusion', 'tagged_regex.db')]
# Incorrect predictions: [('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Latency', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Iteration', 'specific_regex.db'), ('Number of samples', 'specific_regex.db'), ('Number of Variables', 'specific_regex.db'), ('IEEE International Parallel and Distributed Processing Symposium', 'specific_regex.db'), ('Latency', 'voting_policy.db'), ('Iteration', 'voting_policy.db'), ('IEEE International Parallel and Distributed Processing Symposium', 'voting_policy.db'), ('Iteration', 'local_llms.db'), ('Iteration', 'local_llms.db'), ('Iteration', 'local_llms.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Latency', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Iteration', 'generic_regex.db'), ('Number of samples', 'generic_regex.db'), ('Number of Variables', 'generic_regex.db'), ('IEEE International Parallel and Distributed Processing Symposium', 'generic_regex.db'), ('Acknowledgements', 'extern_llm-gemini.db')]
#
# PDF: alves2020-icpe
# Manual sections: {'BACKGROUND AND RELATED WORK', 'INTRODUCTION', 'DISCUSSION', 'DESIGN STUDY', 'CONCLUSION', 'RESULTS', 'THREATS TO VALIDITY'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('BACKGROUND AND RELATED WORK', 'specific_regex.db'), ('DESIGN STUDY', 'specific_regex.db'), ('RESULTS', 'specific_regex.db'), ('DISCUSSION', 'specific_regex.db'), ('THREATS TO VALIDITY', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('INTRODUCTION', 'voting_policy.db'), ('BACKGROUND AND RELATED WORK', 'voting_policy.db'), ('DESIGN STUDY', 'voting_policy.db'), ('RESULTS', 'voting_policy.db'), ('DISCUSSION', 'voting_policy.db'), ('THREATS TO VALIDITY', 'voting_policy.db'), ('CONCLUSION', 'voting_policy.db'), ('INTRODUCTION', 'local_llms.db'), ('DESIGN STUDY', 'local_llms.db'), ('RESULTS', 'local_llms.db'), ('DISCUSSION', 'local_llms.db'), ('CONCLUSION', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('BACKGROUND AND RELATED WORK', 'generic_regex.db'), ('DESIGN STUDY', 'generic_regex.db'), ('RESULTS', 'generic_regex.db'), ('DISCUSSION', 'generic_regex.db'), ('THREATS TO VALIDITY', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('BACKGROUND AND RELATED WORK', 'ORC_tag_extraction.db'), ('DESIGN STUDY', 'ORC_tag_extraction.db'), ('RESULTS', 'ORC_tag_extraction.db'), ('DISCUSSION', 'ORC_tag_extraction.db'), ('THREATS TO VALIDITY', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('BACKGROUND AND RELATED WORK', 'extern_llm-gemini.db'), ('DESIGN STUDY', 'extern_llm-gemini.db'), ('RESULTS', 'extern_llm-gemini.db'), ('DISCUSSION', 'extern_llm-gemini.db'), ('THREATS TO VALIDITY', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('BACKGROUND AND RELATED WORK', 'tagged_regex.db'), ('DESIGN STUDY', 'tagged_regex.db'), ('RESULTS', 'tagged_regex.db'), ('DISCUSSION', 'tagged_regex.db'), ('THREATS TO VALIDITY', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db')]
# Incorrect predictions: [('Frequency', 'specific_regex.db'), ('Frequency', 'specific_regex.db'), ('Frequency', 'generic_regex.db'), ('Frequency', 'generic_regex.db'), ('Interpretable', 'generic_regex.db'), ('Uniform Random Sampling Product Configurations of Feature Models that', 'generic_regex.db'), ('ACKNOWLEDGMENTS', 'extern_llm-gemini.db'), ('Interpretable', 'tagged_regex.db'), ('Uniform Random Sampling Product Configurations of Feature Models that', 'tagged_regex.db')]
#
# PDF: chen2023
# Manual sections: {'INTRODUCTION', 'DISCUSSION', 'DATA COLLECTION', 'PRELIMINARY STUDY', 'CONCLUSION', 'RELATED WORK', 'DATA AVAILABILITY', 'BACKGROUND', 'THREATS TO VALIDITY', 'PREDICTING IOPV PROBLEMS'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('BACKGROUND', 'specific_regex.db'), ('DATA COLLECTION', 'specific_regex.db'), ('PRELIMINARY STUDY', 'specific_regex.db'), ('PREDICTING IOPV PROBLEMS', 'specific_regex.db'), ('DISCUSSION', 'specific_regex.db'), ('THREATS TO VALIDITY', 'specific_regex.db'), ('RELATED WORK', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('DATA AVAILABILITY', 'specific_regex.db'), ('INTRODUCTION', 'voting_policy.db'), ('DATA AVAILABILITY', 'voting_policy.db'), ('BACKGROUND', 'voting_policy.db'), ('DATA COLLECTION', 'voting_policy.db'), ('PREDICTING IOPV PROBLEMS', 'voting_policy.db'), ('DISCUSSION', 'voting_policy.db'), ('THREATS TO VALIDITY', 'voting_policy.db'), ('RELATED WORK', 'voting_policy.db'), ('CONCLUSION', 'voting_policy.db'), ('INTRODUCTION', 'local_llms.db'), ('BACKGROUND', 'local_llms.db'), ('DATA COLLECTION', 'local_llms.db'), ('PREDICTING IOPV PROBLEMS', 'local_llms.db'), ('RELATED WORK', 'local_llms.db'), ('CONCLUSION', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('BACKGROUND', 'generic_regex.db'), ('DATA COLLECTION', 'generic_regex.db'), ('PRELIMINARY STUDY', 'generic_regex.db'), ('PREDICTING IOPV PROBLEMS', 'generic_regex.db'), ('DISCUSSION', 'generic_regex.db'), ('THREATS TO VALIDITY', 'generic_regex.db'), ('RELATED WORK', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('DATA AVAILABILITY', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('BACKGROUND', 'ORC_tag_extraction.db'), ('DATA COLLECTION', 'ORC_tag_extraction.db'), ('PRELIMINARY STUDY', 'ORC_tag_extraction.db'), ('PREDICTING IOPV PROBLEMS', 'ORC_tag_extraction.db'), ('DISCUSSION', 'ORC_tag_extraction.db'), ('THREATS TO VALIDITY', 'ORC_tag_extraction.db'), ('RELATED WORK', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('DATA AVAILABILITY', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('BACKGROUND', 'extern_llm-gemini.db'), ('DATA COLLECTION', 'extern_llm-gemini.db'), ('PRELIMINARY STUDY', 'extern_llm-gemini.db'), ('PREDICTING IOPV PROBLEMS', 'extern_llm-gemini.db'), ('DISCUSSION', 'extern_llm-gemini.db'), ('THREATS TO VALIDITY', 'extern_llm-gemini.db'), ('RELATED WORK', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('DATA AVAILABILITY', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('BACKGROUND', 'tagged_regex.db'), ('DATA COLLECTION', 'tagged_regex.db'), ('PRELIMINARY STUDY', 'tagged_regex.db'), ('PREDICTING IOPV PROBLEMS', 'tagged_regex.db'), ('DISCUSSION', 'tagged_regex.db'), ('THREATS TO VALIDITY', 'tagged_regex.db'), ('RELATED WORK', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db'), ('DATA AVAILABILITY', 'tagged_regex.db')]
# Incorrect predictions: [('Cassandra', 'specific_regex.db'), ('Cassandra', 'specific_regex.db'), ('Cassandra', 'specific_regex.db'), ('CPU', 'specific_regex.db'), ('Memory', 'specific_regex.db'), ('Any metric', 'specific_regex.db'), ('Cassandra', 'specific_regex.db'), ('CPU', 'specific_regex.db'), ('Memory', 'specific_regex.db'), ('Any metric', 'specific_regex.db'), ('Cassandra', 'voting_policy.db'), ('Memory', 'voting_policy.db'), ('Any metric', 'voting_policy.db'), ('Any metric', 'voting_policy.db'), ('Cassandra', 'voting_policy.db'), ('CPU', 'voting_policy.db'), ('Cassandra', 'voting_policy.db'), ('Memory', 'voting_policy.db'), ('CPU', 'voting_policy.db'), ('Identifying', 'local_llms.db'), ('Evaluating', 'local_llms.db'), ('Identifying', 'local_llms.db'), ('Filtering', 'generic_regex.db'), ('Identifying', 'generic_regex.db'), ('Evaluating', 'generic_regex.db'), ('Statistical', 'generic_regex.db'), ('Extracting', 'generic_regex.db'), ('Identifying', 'generic_regex.db'), ('Discretizing CTO', 'generic_regex.db'), ('Cassandra', 'generic_regex.db'), ('Cassandra', 'generic_regex.db'), ('Cassandra', 'generic_regex.db'), ('CPU', 'generic_regex.db'), ('Memory', 'generic_regex.db'), ('Any metric', 'generic_regex.db'), ('Cassandra', 'generic_regex.db'), ('CPU', 'generic_regex.db'), ('Memory', 'generic_regex.db'), ('Any metric', 'generic_regex.db'), ('Filtering', 'tagged_regex.db'), ('Identifying', 'tagged_regex.db'), ('Evaluating', 'tagged_regex.db'), ('Statistical', 'tagged_regex.db'), ('Extracting', 'tagged_regex.db'), ('Identifying', 'tagged_regex.db'), ('Discretizing CTO', 'tagged_regex.db'), ('CPU', 'tagged_regex.db'), ('Memory', 'tagged_regex.db'), ('Any metric', 'tagged_regex.db'), ('CPU', 'tagged_regex.db'), ('Memory', 'tagged_regex.db'), ('Any metric', 'tagged_regex.db')]
#
# PDF: mehlstäubl2022
# Manual sections: set()
# Correct predictions: []
# Incorrect predictions: [('Introduction ', 'specific_regex.db'), ('State of the Art ', 'specific_regex.db'), ('Methodical Approach to Predict Values of Product Attributes ', 'specific_regex.db'), ('Discussion ', 'specific_regex.db'), ('Conclusion and Outlook ', 'specific_regex.db')]
#
# PDF: schmid2022
# Manual sections: {'FOUNDATIONS', 'APPROACH', 'CASE STUDIES', 'EVALUATION', 'INTRODUCTION', 'CONCLUSION', 'RELATED WORK', 'MODELING WORKFLOWS'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('FOUNDATIONS', 'specific_regex.db'), ('APPROACH', 'specific_regex.db'), ('MODELING WORKFLOWS', 'specific_regex.db'), ('CASE STUDIES', 'specific_regex.db'), ('EVALUATION', 'specific_regex.db'), ('RELATED WORK', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('INTRODUCTION', 'voting_policy.db'), ('FOUNDATIONS', 'voting_policy.db'), ('APPROACH', 'voting_policy.db'), ('MODELING WORKFLOWS', 'voting_policy.db'), ('CASE STUDIES', 'voting_policy.db'), ('EVALUATION', 'voting_policy.db'), ('RELATED WORK', 'voting_policy.db'), ('CONCLUSION', 'voting_policy.db'), ('INTRODUCTION', 'generic_regex.db'), ('FOUNDATIONS', 'generic_regex.db'), ('APPROACH', 'generic_regex.db'), ('MODELING WORKFLOWS', 'generic_regex.db'), ('CASE STUDIES', 'generic_regex.db'), ('EVALUATION', 'generic_regex.db'), ('RELATED WORK', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('FOUNDATIONS', 'ORC_tag_extraction.db'), ('APPROACH', 'ORC_tag_extraction.db'), ('MODELING WORKFLOWS', 'ORC_tag_extraction.db'), ('CASE STUDIES', 'ORC_tag_extraction.db'), ('EVALUATION', 'ORC_tag_extraction.db'), ('RELATED WORK', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('FOUNDATIONS', 'extern_llm-gemini.db'), ('APPROACH', 'extern_llm-gemini.db'), ('MODELING WORKFLOWS', 'extern_llm-gemini.db'), ('CASE STUDIES', 'extern_llm-gemini.db'), ('EVALUATION', 'extern_llm-gemini.db'), ('RELATED WORK', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('FOUNDATIONS', 'tagged_regex.db'), ('APPROACH', 'tagged_regex.db'), ('MODELING WORKFLOWS', 'tagged_regex.db'), ('CASE STUDIES', 'tagged_regex.db'), ('EVALUATION', 'tagged_regex.db'), ('RELATED WORK', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db')]
# Incorrect predictions: [('Core hours', 'specific_regex.db'), ('Core hours', 'generic_regex.db'), ('Using Compiler Techniques to Improve Automatic Performance', 'generic_regex.db'), ('Using automated performance modeling to find scalability bugs', 'generic_regex.db'), ('ACKNOWLEDGMENTS', 'extern_llm-gemini.db'), ('Using Compiler Techniques to Improve Automatic Performance', 'tagged_regex.db'), ('Using automated performance modeling to find scalability bugs', 'tagged_regex.db')]
#
# PDF: damasceno2019
# Manual sections: {'THE FFSMDiff ALGORITHM', 'INTRODUCTION', 'CONCLUSION', 'RELATED WORK', 'EMPIRICAL EVALUATION', 'PRELIMINARIES'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('PRELIMINARIES', 'specific_regex.db'), ('THE FFSMDiff ALGORITHM', 'specific_regex.db'), ('EMPIRICAL EVALUATION', 'specific_regex.db'), ('RELATED WORK', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('INTRODUCTION', 'voting_policy.db'), ('PRELIMINARIES', 'voting_policy.db'), ('THE FFSMDiff ALGORITHM', 'voting_policy.db'), ('EMPIRICAL EVALUATION', 'voting_policy.db'), ('RELATED WORK', 'voting_policy.db'), ('CONCLUSION', 'voting_policy.db'), ('INTRODUCTION', 'local_llms.db'), ('PRELIMINARIES', 'local_llms.db'), ('THE FFSMDiff ALGORITHM', 'local_llms.db'), ('EMPIRICAL EVALUATION', 'local_llms.db'), ('RELATED WORK', 'local_llms.db'), ('CONCLUSION', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('PRELIMINARIES', 'generic_regex.db'), ('THE FFSMDiff ALGORITHM', 'generic_regex.db'), ('EMPIRICAL EVALUATION', 'generic_regex.db'), ('RELATED WORK', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('PRELIMINARIES', 'ORC_tag_extraction.db'), ('THE FFSMDiff ALGORITHM', 'ORC_tag_extraction.db'), ('EMPIRICAL EVALUATION', 'ORC_tag_extraction.db'), ('RELATED WORK', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('PRELIMINARIES', 'extern_llm-gemini.db'), ('THE FFSMDiff ALGORITHM', 'extern_llm-gemini.db'), ('EMPIRICAL EVALUATION', 'extern_llm-gemini.db'), ('RELATED WORK', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('PRELIMINARIES', 'tagged_regex.db'), ('THE FFSMDiff ALGORITHM', 'tagged_regex.db'), ('EMPIRICAL EVALUATION', 'tagged_regex.db'), ('RELATED WORK', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db')]
# Incorrect predictions: [('The size of learnt FFSMs is larger than the total', 'specific_regex.db'), ('The size of learnt FFSMs is at most equal to the', 'specific_regex.db'), ('The size of learnt FFSMs is not influenced by', 'specific_regex.db'), ('The size of learnt FFSMs is influenced by the', 'specific_regex.db'), ('The learnt FFSMs have at most the same size as', 'specific_regex.db'), ('All the FSMs used in this study were derived from FFSMs using', 'specific_regex.db'), ('AGM', 'specific_regex.db'), ('Percentage of products analyzed', 'specific_regex.db'), ('AGM', 'specific_regex.db'), ('The size of learnt FFSMs is not influenced by', 'voting_policy.db'), ('Percentage of products analyzed', 'voting_policy.db'), ('The size of learnt FFSMs is larger than the total', 'local_llms.db'), ('The size of learnt FFSMs is larger than the total', 'generic_regex.db'), ('The size of learnt FFSMs is at most equal to the', 'generic_regex.db'), ('The size of learnt FFSMs is not influenced by', 'generic_regex.db'), ('The size of learnt FFSMs is influenced by the', 'generic_regex.db'), ('The learnt FFSMs have at most the same size as', 'generic_regex.db'), ('All the FSMs used in this study were derived from FFSMs using', 'generic_regex.db'), ('AGM', 'generic_regex.db'), ('Percentage of products analyzed', 'generic_regex.db'), ('AGM', 'generic_regex.db'), ('ACKNOWLEDGMENTS', 'extern_llm-gemini.db')]
#
# PDF: li2020-ase
# Manual sections: {'EXPERIMENTAL SETUP', 'INTRODUCTION', 'BI-LEVEL PROGRAMMING FOR AUTOMATED CPDP MODEL DISCOVERY', 'CONCLUSION', 'RELATED WORK', 'BI-LEVEL PROGRAMMING', 'RESULTS AND DISCUSSIONS', 'THREATS TO VALIDITY'}
# Correct predictions: [('INTRODUCTION', 'specific_regex.db'), ('EXPERIMENTAL SETUP', 'specific_regex.db'), ('RESULTS AND DISCUSSIONS', 'specific_regex.db'), ('RELATED WORK', 'specific_regex.db'), ('THREATS TO VALIDITY', 'specific_regex.db'), ('CONCLUSION', 'specific_regex.db'), ('INTRODUCTION', 'voting_policy.db'), ('EXPERIMENTAL SETUP', 'voting_policy.db'), ('RESULTS AND DISCUSSIONS', 'voting_policy.db'), ('RELATED WORK', 'voting_policy.db'), ('THREATS TO VALIDITY', 'voting_policy.db'), ('CONCLUSION', 'voting_policy.db'), ('INTRODUCTION', 'local_llms.db'), ('EXPERIMENTAL SETUP', 'local_llms.db'), ('THREATS TO VALIDITY', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('EXPERIMENTAL SETUP', 'generic_regex.db'), ('RESULTS AND DISCUSSIONS', 'generic_regex.db'), ('RELATED WORK', 'generic_regex.db'), ('THREATS TO VALIDITY', 'generic_regex.db'), ('CONCLUSION', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('EXPERIMENTAL SETUP', 'ORC_tag_extraction.db'), ('RESULTS AND DISCUSSIONS', 'ORC_tag_extraction.db'), ('RELATED WORK', 'ORC_tag_extraction.db'), ('THREATS TO VALIDITY', 'ORC_tag_extraction.db'), ('CONCLUSION', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('BI-LEVEL PROGRAMMING', 'extern_llm-gemini.db'), ('EXPERIMENTAL SETUP', 'extern_llm-gemini.db'), ('RESULTS AND DISCUSSIONS', 'extern_llm-gemini.db'), ('RELATED WORK', 'extern_llm-gemini.db'), ('THREATS TO VALIDITY', 'extern_llm-gemini.db'), ('CONCLUSION', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('EXPERIMENTAL SETUP', 'tagged_regex.db'), ('RESULTS AND DISCUSSIONS', 'tagged_regex.db'), ('RELATED WORK', 'tagged_regex.db'), ('THREATS TO VALIDITY', 'tagged_regex.db'), ('CONCLUSION', 'tagged_regex.db')]
# Incorrect predictions: [('Randomly initialize a valid combination of transfer learner', 'specific_regex.db'), ('Randomly initialize a valid combination of transfer learner', 'generic_regex.db'), ('ACKNOWLEDGEMENT', 'extern_llm-gemini.db')]
#
# PDF: Iorio2019
# Manual sections: {'NTRODUCTION', 'EXPERIMENTAL RESULTS', 'CONCLUSION AND FUTURE WORK', 'MODEL MAPPING', 'RELATED WORK', 'EXPERIMENTAL PLATFORM', 'IRECT AND INCREMENTAL MODELS USED FOR COMPARISON'}
# Correct predictions: [('RELATED WORK', 'specific_regex.db'), ('MODEL MAPPING', 'specific_regex.db'), ('EXPERIMENTAL PLATFORM', 'specific_regex.db'), ('EXPERIMENTAL RESULTS', 'specific_regex.db'), ('CONCLUSION AND FUTURE WORK', 'specific_regex.db'), ('RELATED WORK', 'local_llms.db'), ('EXPERIMENTAL PLATFORM', 'local_llms.db'), ('EXPERIMENTAL RESULTS', 'local_llms.db'), ('CONCLUSION AND FUTURE WORK', 'local_llms.db'), ('RELATED WORK', 'generic_regex.db'), ('MODEL MAPPING', 'generic_regex.db'), ('EXPERIMENTAL PLATFORM', 'generic_regex.db'), ('EXPERIMENTAL RESULTS', 'generic_regex.db'), ('CONCLUSION AND FUTURE WORK', 'generic_regex.db'), ('RELATED WORK', 'ORC_tag_extraction.db'), ('MODEL MAPPING', 'ORC_tag_extraction.db'), ('EXPERIMENTAL PLATFORM', 'ORC_tag_extraction.db'), ('EXPERIMENTAL RESULTS', 'ORC_tag_extraction.db'), ('CONCLUSION AND FUTURE WORK', 'ORC_tag_extraction.db'), ('RELATED WORK', 'extern_llm-gemini.db'), ('MODEL MAPPING', 'extern_llm-gemini.db'), ('EXPERIMENTAL PLATFORM', 'extern_llm-gemini.db'), ('EXPERIMENTAL RESULTS', 'extern_llm-gemini.db'), ('CONCLUSION AND FUTURE WORK', 'extern_llm-gemini.db'), ('RELATED WORK', 'tagged_regex.db'), ('MODEL MAPPING', 'tagged_regex.db'), ('EXPERIMENTAL PLATFORM', 'tagged_regex.db'), ('EXPERIMENTAL RESULTS', 'tagged_regex.db'), ('CONCLUSION AND FUTURE WORK', 'tagged_regex.db')]
# Incorrect predictions: [('INTRODUCTION', 'specific_regex.db'), ('DIRECT AND INCREMENTAL MODELS USED FOR', 'specific_regex.db'), ('INTRODUCTION', 'local_llms.db'), ('DIRECT AND INCREMENTAL MODELS USED FOR', 'local_llms.db'), ('GaussianProcessRegressor', 'local_llms.db'), ('INTRODUCTION', 'generic_regex.db'), ('DIRECT AND INCREMENTAL MODELS USED FOR', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('Buffer', 'generic_regex.db'), ('Throughput', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('GaussianProcessRegressor', 'generic_regex.db'), ('INTRODUCTION', 'ORC_tag_extraction.db'), ('DIRECT AND INCREMENTAL MODELS USED FOR COMPARISON', 'ORC_tag_extraction.db'), ('INTRODUCTION', 'extern_llm-gemini.db'), ('INTRODUCTION', 'tagged_regex.db'), ('DIRECT AND INCREMENTAL MODELS USED FOR', 'tagged_regex.db')]
#
# PDF: Arcaini2020
# Manual sections: {'Threats to validity', 'Related work', 'Introduction', 'Background', 'Conclusion', 'Experimentation', 'Proposed approach'}
# Correct predictions: [('Introduction', 'ORC_tag_extraction.db'), ('Background', 'ORC_tag_extraction.db'), ('Proposed approach', 'ORC_tag_extraction.db'), ('Experimentation', 'ORC_tag_extraction.db'), ('Threats to validity', 'ORC_tag_extraction.db'), ('Related work', 'ORC_tag_extraction.db'), ('Conclusion', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('Background', 'extern_llm-gemini.db'), ('Proposed approach', 'extern_llm-gemini.db'), ('Experimentation', 'extern_llm-gemini.db'), ('Threats to validity', 'extern_llm-gemini.db'), ('Related work', 'extern_llm-gemini.db'), ('Conclusion', 'extern_llm-gemini.db')]
# Incorrect predictions: [('Introduction ', 'specific_regex.db'), ('Background ', 'specific_regex.db'), ('Proposed approach ', 'specific_regex.db'), ('Experimentation ', 'specific_regex.db'), ('Threats to validity ', 'specific_regex.db'), ('Related work ', 'specific_regex.db'), ('Conclusion ', 'specific_regex.db'), ('Introduction ', 'generic_regex.db'), ('Background ', 'generic_regex.db'), ('Proposed approach ', 'generic_regex.db'), ('Experimentation ', 'generic_regex.db'), ('Some of the feature models generated by BeTTy were not successfully parsed ', 'generic_regex.db'), ('Threats to validity ', 'generic_regex.db'), ('Related work ', 'generic_regex.db'), ('Conclusion ', 'generic_regex.db'), ('Declaration of Competing Interest', 'extern_llm-gemini.db'), ('CRediT authorship contribution statement', 'extern_llm-gemini.db'), ('Acknowledgments', 'extern_llm-gemini.db')]
#
# PDF: Iqbal2022
# Manual sections: {'Scalability', 'Case Study', 'Limitations and Future Directions', 'Introduction', 'Related Work', 'Causal Reasoning for Systems', 'Unicorn', 'Evaluation', 'Motivating Scenarios', 'Effectiveness and Sample Efficiency', 'Transferability', 'Conclusion'}
# Correct predictions: [('Introduction', 'specific_regex.db'), ('Motivating Scenarios', 'specific_regex.db'), ('Causal Reasoning for Systems', 'specific_regex.db'), ('Unicorn', 'specific_regex.db'), ('Case Study', 'specific_regex.db'), ('Evaluation', 'specific_regex.db'), ('Effectiveness and Sample Efficiency', 'specific_regex.db'), ('Transferability', 'specific_regex.db'), ('Scalability', 'specific_regex.db'), ('Related Work', 'specific_regex.db'), ('Limitations and Future Directions', 'specific_regex.db'), ('Conclusion', 'specific_regex.db'), ('Introduction', 'voting_policy.db'), ('Related Work', 'voting_policy.db'), ('Limitations and Future Directions', 'voting_policy.db'), ('Conclusion', 'voting_policy.db'), ('Causal Reasoning for Systems', 'voting_policy.db'), ('Case Study', 'voting_policy.db'), ('Evaluation', 'voting_policy.db'), ('Effectiveness and Sample Efficiency', 'voting_policy.db'), ('Transferability', 'voting_policy.db'), ('Scalability', 'voting_policy.db'), ('Introduction', 'local_llms.db'), ('Motivating Scenarios', 'local_llms.db'), ('Causal Reasoning for Systems', 'local_llms.db'), ('Effectiveness and Sample Efficiency', 'local_llms.db'), ('Related Work', 'local_llms.db'), ('Limitations and Future Directions', 'local_llms.db'), ('Conclusion', 'local_llms.db'), ('Introduction', 'generic_regex.db'), ('Motivating Scenarios', 'generic_regex.db'), ('Causal Reasoning for Systems', 'generic_regex.db'), ('Unicorn', 'generic_regex.db'), ('Case Study', 'generic_regex.db'), ('Evaluation', 'generic_regex.db'), ('Effectiveness and Sample Efficiency', 'generic_regex.db'), ('Transferability', 'generic_regex.db'), ('Scalability', 'generic_regex.db'), ('Related Work', 'generic_regex.db'), ('Limitations and Future Directions', 'generic_regex.db'), ('Conclusion', 'generic_regex.db'), ('Introduction', 'ORC_tag_extraction.db'), ('Motivating Scenarios', 'ORC_tag_extraction.db'), ('Causal Reasoning for Systems', 'ORC_tag_extraction.db'), ('Unicorn', 'ORC_tag_extraction.db'), ('Case Study', 'ORC_tag_extraction.db'), ('Evaluation', 'ORC_tag_extraction.db'), ('Effectiveness and Sample Efficiency', 'ORC_tag_extraction.db'), ('Transferability', 'ORC_tag_extraction.db'), ('Scalability', 'ORC_tag_extraction.db'), ('Related Work', 'ORC_tag_extraction.db'), ('Limitations and Future Directions', 'ORC_tag_extraction.db'), ('Conclusion', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('Motivating Scenarios', 'extern_llm-gemini.db'), ('Causal Reasoning for Systems', 'extern_llm-gemini.db'), ('Case Study', 'extern_llm-gemini.db'), ('Evaluation', 'extern_llm-gemini.db'), ('Effectiveness and Sample Efficiency', 'extern_llm-gemini.db'), ('Transferability', 'extern_llm-gemini.db'), ('Scalability', 'extern_llm-gemini.db'), ('Related Work', 'extern_llm-gemini.db'), ('Limitations and Future Directions', 'extern_llm-gemini.db'), ('Conclusion', 'extern_llm-gemini.db'), ('Introduction', 'tagged_regex.db'), ('Motivating Scenarios', 'tagged_regex.db'), ('Causal Reasoning for Systems', 'tagged_regex.db'), ('Unicorn', 'tagged_regex.db'), ('Case Study', 'tagged_regex.db'), ('Evaluation', 'tagged_regex.db'), ('Effectiveness and Sample Efficiency', 'tagged_regex.db'), ('Transferability', 'tagged_regex.db'), ('Scalability', 'tagged_regex.db'), ('Related Work', 'tagged_regex.db'), ('Limitations and Future Directions', 'tagged_regex.db'), ('Conclusion', 'tagged_regex.db')]
# ...
# Manual sections: {'Related work', 'Introduction', 'Background', 'MCTS conceptual framework for feature model analyses', 'Implementation of the MCTS framework', 'Configuration based analysis', 'Conclusion and future work', 'Analysis with feature models as states'}
# Correct predictions: [('Introduction', 'specific_regex.db'), ('Background', 'specific_regex.db'), ('MCTS conceptual framework for feature model analyses', 'specific_regex.db'), ('Implementation of the MCTS framework', 'specific_regex.db'), ('Configuration based analysis', 'specific_regex.db'), ('Analysis with feature models as states', 'specific_regex.db'), ('Related work', 'specific_regex.db'), ('Introduction', 'voting_policy.db'), ('Background', 'voting_policy.db'), ('MCTS conceptual framework for feature model analyses', 'voting_policy.db'), ('Implementation of the MCTS framework', 'voting_policy.db'), ('Configuration based analysis', 'voting_policy.db'), ('Analysis with feature models as states', 'voting_policy.db'), ('Related work', 'voting_policy.db'), ('Introduction', 'local_llms.db'), ('Background', 'local_llms.db'), ('MCTS conceptual framework for feature model analyses', 'local_llms.db'), ('Configuration based analysis', 'local_llms.db'), ('Analysis with feature models as states', 'local_llms.db'), ('Related work', 'local_llms.db'), ('Introduction', 'generic_regex.db'), ('Background', 'generic_regex.db'), ('MCTS conceptual framework for feature model analyses', 'generic_regex.db'), ('Implementation of the MCTS framework', 'generic_regex.db'), ('Configuration based analysis', 'generic_regex.db'), ('Analysis with feature models as states', 'generic_regex.db'), ('Related work', 'generic_regex.db'), ('Introduction', 'ORC_tag_extraction.db'), ('Background', 'ORC_tag_extraction.db'), ('MCTS conceptual framework for feature model analyses', 'ORC_tag_extraction.db'), ('Implementation of the MCTS framework', 'ORC_tag_extraction.db'), ('Configuration based analysis', 'ORC_tag_extraction.db'), ('Analysis with feature models as states', 'ORC_tag_extraction.db'), ('Related work', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('Background', 'extern_llm-gemini.db'), ('MCTS conceptual framework for feature model analyses', 'extern_llm-gemini.db'), ('Implementation of the MCTS framework', 'extern_llm-gemini.db'), ('Configuration based analysis', 'extern_llm-gemini.db'), ('Analysis with feature models as states', 'extern_llm-gemini.db'), ('Related work', 'extern_llm-gemini.db'), ('Introduction', 'tagged_regex.db'), ('Background', 'tagged_regex.db'), ('MCTS conceptual framework for feature model analyses', 'tagged_regex.db'), ('Implementation of the MCTS framework', 'tagged_regex.db'), ('Configuration based analysis', 'tagged_regex.db'), ('Analysis with feature models as states', 'tagged_regex.db'), ('Related work', 'tagged_regex.db')]
# Incorrect predictions: [('Conclusions and future work', 'specific_regex.db'), ('Conclusions and future work', 'voting_policy.db'), ('Conclusions and future work', 'local_llms.db'), ('An atomic set is a group of features that can be treated as a unit when', 'generic_regex.db'), ('Conclusions and future work', 'generic_regex.db'), ('Conclusions and future work', 'ORC_tag_extraction.db'), ('Conclusions and future work', 'extern_llm-gemini.db'), ('Material', 'extern_llm-gemini.db'), ('Declaration of competing interest', 'extern_llm-gemini.db'), ('Data availability', 'extern_llm-gemini.db'), ('Acknowledgments', 'extern_llm-gemini.db'), ('Conclusions and future work', 'tagged_regex.db')]
#
# PDF: Xiang2022
# Manual sections: {'Threats to validity', 'Related work', 'Our proposal', 'Introduction', 'Experimental setup', 'Conclusion', 'Experimental results', 'Preliminaries'}
# Correct predictions: [('Introduction', 'extern_llm-gemini.db')]
# Incorrect predictions: [('Page 44 of 45', 'voting_policy.db'), ('Authors and Affiliations', 'ORC_tag_extraction.db'), ('Acknowledgements', 'extern_llm-gemini.db'), ('Authors and Affiliations', 'extern_llm-gemini.db')]
#
# PDF: mehlstäubl2022
# Manual sections: {'Methodical Approach to Predict Values of Product Attributes', 'Introduction', 'Case Study: Prediction of Weights for Commercial Vehicles', 'State of the Art', 'Discussion', 'Conclusion and Outlook'}
# Correct predictions: [('Introduction', 'ORC_tag_extraction.db'), ('State of the Art', 'ORC_tag_extraction.db'), ('Methodical Approach to Predict Values of Product Attributes', 'ORC_tag_extraction.db'), ('Discussion', 'ORC_tag_extraction.db'), ('Conclusion and Outlook', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('State of the Art', 'extern_llm-gemini.db'), ('Methodical Approach to Predict Values of Product Attributes', 'extern_llm-gemini.db'), ('Case Study: Prediction of Weights for Commercial Vehicles', 'extern_llm-gemini.db'), ('Discussion', 'extern_llm-gemini.db'), ('Conclusion and Outlook', 'extern_llm-gemini.db')]
# Incorrect predictions: [('Introduction ', 'voting_policy.db'), ('State of the Art ', 'voting_policy.db'), ('Methodical Approach to Predict Values of Product Attributes ', 'voting_policy.db'), ('Discussion ', 'voting_policy.db'), ('Conclusion and Outlook ', 'voting_policy.db'), ('Introduction ', 'local_llms.db'), ('Methodical Approach to Predict Values of Product Attributes ', 'local_llms.db'), ('Conclusion and Outlook ', 'local_llms.db'), ('Introduction ', 'generic_regex.db'), ('State of the Art ', 'generic_regex.db'), ('Methodical Approach to Predict Values of Product Attributes ', 'generic_regex.db'), ('Discussion ', 'generic_regex.db'), ('MAE', 'generic_regex.db'), ('MAPE', 'generic_regex.db'), ('Predicted Values in kg', 'generic_regex.db'), ('Conclusion and Outlook ', 'generic_regex.db'), ('Acknowledgement', 'extern_llm-gemini.db'), ('Introduction ', 'tagged_regex.db'), ('State of the Art ', 'tagged_regex.db'), ('Methodical Approach to Predict Values of Product Attributes ', 'tagged_regex.db'), ('Discussion ', 'tagged_regex.db'), ('Conclusion and Outlook ', 'tagged_regex.db')]
#
# PDF: tërnava2022
# Manual sections: {'Threats to validity', 'Results', 'Background and motivation', 'Introduction', 'Related Work', 'Conclusion', 'Experimental Protocol', 'Discussion', 'Research questions'}
# Correct predictions: [('Introduction', 'voting_policy.db'), ('Background and motivation', 'voting_policy.db'), ('Research questions', 'voting_policy.db'), ('Experimental Protocol', 'voting_policy.db'), ('Results', 'voting_policy.db'), ('Discussion', 'voting_policy.db'), ('Threats to validity', 'voting_policy.db'), ('Related Work', 'voting_policy.db'), ('Conclusion', 'voting_policy.db'), ('Introduction', 'local_llms.db'), ('Background and motivation', 'local_llms.db'), ('Results', 'local_llms.db'), ('Discussion', 'local_llms.db'), ('Conclusion', 'local_llms.db'), ('Introduction', 'generic_regex.db'), ('Background and motivation', 'generic_regex.db'), ('Research questions', 'generic_regex.db'), ('Experimental Protocol', 'generic_regex.db'), ('Results', 'generic_regex.db'), ('Discussion', 'generic_regex.db'), ('Threats to validity', 'generic_regex.db'), ('Related Work', 'generic_regex.db'), ('Conclusion', 'generic_regex.db'), ('Introduction', 'ORC_tag_extraction.db'), ('Background and motivation', 'ORC_tag_extraction.db'), ('Research questions', 'ORC_tag_extraction.db'), ('Experimental Protocol', 'ORC_tag_extraction.db'), ('Results', 'ORC_tag_extraction.db'), ('Discussion', 'ORC_tag_extraction.db'), ('Threats to validity', 'ORC_tag_extraction.db'), ('Related Work', 'ORC_tag_extraction.db'), ('Conclusion', 'ORC_tag_extraction.db'), ('Introduction', 'extern_llm-gemini.db'), ('Background and motivation', 'extern_llm-gemini.db'), ('Research questions', 'extern_llm-gemini.db'), ('Experimental Protocol', 'extern_llm-gemini.db'), ('Results', 'extern_llm-gemini.db'), ('Discussion', 'extern_llm-gemini.db'), ('Threats to validity', 'extern_llm-gemini.db'), ('Related Work', 'extern_llm-gemini.db'), ('Conclusion', 'extern_llm-gemini.db'), ('Introduction', 'tagged_regex.db'), ('Background and motivation', 'tagged_regex.db'), ('Research questions', 'tagged_regex.db'), ('Experimental Protocol', 'tagged_regex.db'), ('Results', 'tagged_regex.db'), ('Discussion', 'tagged_regex.db'), ('Threats to validity', 'tagged_regex.db'), ('Related Work', 'tagged_regex.db'), ('Conclusion', 'tagged_regex.db')]
# Incorrect predictions: [('INSA Rennes', 'generic_regex.db'), ('Based on our last check on February 2022', 'generic_regex.db'), ('Acknowledgements', 'extern_llm-gemini.db')]
#
# PDF: gonzalez-rojas2019_otm
# Manual sections: {'Null'}
# Correct predictions: []
# Incorrect predictions: [('Manuel Fritz and Holger Schwarz', 'local_llms.db'), ('Peter McBrien and Alexandra Poulovassilis', 'local_llms.db'), ('Giray Havur and Cristina Cabanillas', 'local_llms.db'), ('Jürgen Krauß and Martin Schmollinger', 'local_llms.db'), ('Francesco Sportelli and Enrico Franconi', 'local_llms.db'), ('Introduction', 'local_llms.db'), ('Ontological Foundations', 'local_llms.db'), ('The Ontology of Trust', 'local_llms.db'), ('Use Case Illustrations', 'local_llms.db'), ('Related Work', 'local_llms.db'), ('Motivating Example', 'local_llms.db'), ('Approach Overview', 'local_llms.db'), ('Smart City Exploration Graph', 'local_llms.db'), ('Indicator', 'local_llms.db'), ('Personalised Graphs Exploration', 'local_llms.db'), ('Related Work', 'local_llms.db'), ('Introduction', 'local_llms.db'), ('Characterizing Conceptual Modeling Framework', 'local_llms.db'), ('The Characterizing Conceptual Modeling Research', 'local_llms.db'), ('Conceptual Modeling Context', 'local_llms.db'), ('Evaluating the CCMR Framework', 'local_llms.db'), ('Note that our characterizations of these and the other 3 + 6 papers have not been', 'local_llms.db'), ('Discussion and Related Work', 'local_llms.db'), ('Introduction', 'local_llms.db'), ('The MapSDI Framework', 'local_llms.db'), ('Experimental Study', 'local_llms.db'), ('Related Work', 'local_llms.db'), ('Conclusions and Future Work', 'local_llms.db'), ('Introduction', 'local_llms.db'), ('Related Work', 'local_llms.db'), ('Preliminaries', 'local_llms.db'), ('Activity Context Framework', 'local_llms.db'), ('Approach', 'local_llms.db'), ('Evaluation', 'local_llms.db'), ('Founding Editors', 'generic_regex.db'), ('Manuel Fritz and Holger Schwarz', 'generic_regex.db'), ('Mahnaz Sadat Qafari and Wil van der Aalst', 'generic_regex.db'), ('Peter McBrien and Alexandra Poulovassilis', 'generic_regex.db'), ('Irvin Dongo and Richard Chbeir', 'generic_regex.db'), ('Peggy Richter and Hannes Schlieter', 'generic_regex.db'), ('Giray Havur and Cristina Cabanillas', 'generic_regex.db'), ('Jürgen Krauß and Martin Schmollinger', 'generic_regex.db'), ('Complex Query Augmentation for Question Answering', 'generic_regex.db'), ('Francesco Sportelli and Enrico Franconi', 'generic_regex.db'), ('Contents', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Ontological Foundations', 'generic_regex.db'), ('On Trust', 'generic_regex.db'), ('Deﬁning Social Systems', 'generic_regex.db'), ('The Ontology of Trust', 'generic_regex.db'), ('Use Case Illustrations', 'generic_regex.db'), ('Related Work', 'generic_regex.db'), ('Final Remarks', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Motivating Example', 'generic_regex.db'), ('Approach Overview', 'generic_regex.db'), ('Smart City Semantic Data Lake', 'generic_regex.db'), ('Smart City Exploration Graph', 'generic_regex.db'), ('Indicator', 'generic_regex.db'), ('Personalised Graphs Extraction', 'generic_regex.db'), ('Personalised Graphs Exploration', 'generic_regex.db'), ('Preliminary Validation', 'generic_regex.db'), ('Related Work', 'generic_regex.db'), ('Concluding Remarks', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Characterizing Conceptual Modeling Framework', 'generic_regex.db'), ('The Characterizing Conceptual Modeling Research', 'generic_regex.db'), ('Conceptual Modeling Context', 'generic_regex.db'), ('Evaluating the CCMR Framework', 'generic_regex.db'), ('Note that our characterizations of these and the other 3 + 6 papers have not been', 'generic_regex.db'), ('Discussion and Related Work', 'generic_regex.db'), ('Conclusion', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Motivating Example', 'generic_regex.db'), ('The MapSDI Framework', 'generic_regex.db'), ('Experimental Study', 'generic_regex.db'), ('Related Work', 'generic_regex.db'), ('Conclusions and Future Work', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Related Work', 'generic_regex.db'), ('Preliminaries', 'generic_regex.db'), ('Activi ...
#
# PDF: 978-3-031-61874-1
# Manual sections: set()
# Correct predictions: []
# Incorrect predictions: [('Introduction', 'local_llms.db'), ('Introduction', 'local_llms.db'), ('Feature Modelling', 'local_llms.db'), ('Analysis of Feature Models', 'local_llms.db'), ('Interacting with Feature Model Configurators', 'local_llms.db'), ('Tools and Applications', 'local_llms.db'), ('Introduction', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Introduction', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Relationship', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Relationship', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Feature Modelling', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('An algorithm that can be used for the automated detection of redundant constraints in FMs is', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Analysis of Feature Models', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Interacting with Feature Model Configurators', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db'), ('Tools and Applications', 'generic_regex.db')]
